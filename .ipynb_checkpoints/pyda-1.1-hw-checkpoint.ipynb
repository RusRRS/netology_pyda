# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len(long_phrase)>len(short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
# объем файла в байтах
file_bitesize = int(input("Введите объем файла в байтах: "))
# Расчет пошагово
file_kbsize = file_bitesize / 1024  # объем файла в килобайтах
file_mbsize = file_kbsize / 1024  # объем файла в мегабайтах
print("Объем файла равен ", round(file_mbsize,2), "Mb", sep="")
# Out:
# Введите объем файла в байтах: 3333333333333
# Объем файла равен 3178914.39Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %% [markdown]
# ### Выполнение расчета выполняется исходя из следующих допущений:
# | # | Знак зодиака | Дата начала   | Дата начала |
# |-- |--------------|---------------|-------------|
# |♈| Овен	      |21 марта |	 20 апреля|
# |♉|Телец	   |21 апреля 	 |21 мая|
# |♊|Близнецы	  |22 мая 	| 21 июня|
# |♋|Рак	    |22 июня 	| 22 июля|
# |♌|Лев	    |23 июля 	| 21 августа|
# |♍|Дева	    |22 августа |	 23 сентября|
# |♎|Весы	    |24 сентября |	 23 октября|
# |♏|Скорпион	|24 октября |	 22 ноября|
# |♐|Стрелец	|23 ноября 	| 22 декабря|
# |♑|Козерог	|23 декабря |	 20 января|
# |♒|Водолей	|21 января 	| 19 февраля|
# |♓|Рыбы	    |20 февраля 	| 20 марта|

# %%
# для начала получим месяц:
birth_month_input = input("Введите месяц:") # переменная для получения значения месяца
birth_month = birth_month_input.upper() # оставляем возможность написания с большой буквы

# Теперь получим дату:
try:
    birth_date = int(input("Введите число:"))
    # Убираем несуществующие даты:
    # Дата больше 31
    if birth_date > 31:
        print("Ошибка ввода данных")
    # Дата 29 и 30 февраля
    elif birth_month == "ФЕВРАЛЬ" and birth_date > 28:
        print("Ошибка ввода данных")
    # Дата 30 апреля, июня, сентября и ноября
    elif birth_date == 31 and (birth_month == "АПРЕЛЬ" or \
                               birth_month == "ИЮНЬ" or \
                               birth_month == "СЕНТЯБРЬ" or \
                               birth_month == "НОЯБРЬ"):
        print("Ошибка ввода данных")
    
    # После того, как убрали несуществующие даты, определяем знаки зодиака:
    
    # Блок 02. Козерог (23 декабря - 20 января)
    elif  (birth_month == "ДЕКАБРЬ" and birth_date >= 23) or (birth_month == "ЯНВАРЬ" and birth_date <= 20):
        print("Козерог")

    # Блок 03. Водолей (21 января - 19 февраля)
    elif  (birth_month == "ЯНВАРЬ" and birth_date >= 21) or (birth_month == "ФЕВРАЛЬ" and birth_date <= 19):
        print("Водолей")        
        
    # Блок 04. Рыбы (20 февраля - 20 марта)
    elif  (birth_month == "ФЕВРАЛЬ" and birth_date >= 20) or (birth_month == "МАРТ" and birth_date <= 20):
        print("Рыбы")        
        
    # Блок 05. Овен (21 марта - 19 апреля)
    elif  (birth_month == "МАРТ" and birth_date >= 21) or (birth_month == "АПРЕЛЬ" and birth_date <= 19):
        print("Овен")          
        
    # Блок 06. Телец (21 апреля - 21 мая)
    elif  (birth_month == "АПРЕЛЬ" and birth_date >= 21) or (birth_month == "МАЙ" and birth_date <= 21):
        print("Телец")
    
    # Блок 07. Близнецы (22 мая - 21 июня)
    elif  (birth_month == "МАЙ" and birth_date >= 22) or (birth_month == "ИЮНЬ" and birth_date <= 21):
        print("Близнецы")
    
    # Блок 08. Рак (22 июня - 22 июля)
    elif  (birth_month == "ИЮНЬ" and birth_date >= 22) or (birth_month == "ИЮЛЬ" and birth_date <= 22):
        print("Рак")
        
    # Блок 09. Лев (23 июля - 21 августа)
    elif  (birth_month == "ИЮЛЬ" and birth_date >= 23) or (birth_month == "АВГУСТ" and birth_date <= 21):
        print("Лев")       
        
    # Блок 10. Дева (22 августа - 23 сентября)
    elif  (birth_month == "АВГУСТ" and birth_date >= 22) or (birth_month == "СЕНТЯБРЬ" and birth_date <= 23):
        print("Дева") 

    # Блок 11. Весы (24 сентября - 23 октября)
    elif  (birth_month == "СЕНТЯБРЬ" and birth_date >= 24) or (birth_month == "ОКТЯБРЬ" and birth_date <= 23):
        print("Весы") 

    # Блок 12. Скорпион (24 октября - 22 ноября)
    elif  (birth_month == "ОКТЯБРЬ" and birth_date >= 24) or (birth_month == "НОЯБРЬ" and birth_date <= 23):
        print("Скорпион") 
        
    # Блок 12. Стрелец (23 ноября - 22 декабря)
    elif  (birth_month == "НОЯБРЬ" and birth_date >= 23) or (birth_month == "ДЕКАБРЬ" and birth_date <= 22):
        print("Стрелец")       
        
    else:
        print("Ошибка ввода данных")        

except (TypeError, ValueError):
    print('Ошибка ввода данных')
# Out:
# Введите месяц:Март
# Введите число:6
# Рыбы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
# Вводим исходные показатели, с проверкой на внесение чисел:
try:
    pay_month = int(input("Введите заработанную плату в месяц:"))
    mortgage_month = int(input("Введите сколько процентов уходит на ипотеку:"))
    life_month = int(input("Введите сколько процентов уходит на жизнь:"))
    bonus_count = int(input("Введите количество премий за год:"))

    # Проверяем правильность заполнения процентов:
    if mortgage_month + life_month > 100:
        print("Ошибка в заполнении процентов: больше 100%")
    else:
        # Рассчитываем годовые доходы:
        pay_year = pay_month * 12 # заработная плата за год
        bonus_year = pay_month * bonus_count # годовая премия
        inflow_year = pay_year + bonus_year

        # Рассчитываем годовые расходы:
        mortgage_year = pay_year * mortgage_month / 100 # годовые расходы на ипотеку 
        life_year = pay_year * life_month / 100 # годовые расходы на жизнь
        rest_year = bonus_year / 2 # годовые расходы на отпуск
        flow_year = mortgage_year + life_year + rest_year

        # Рассчитываем итоговый баланс:
        balance = inflow_year - flow_year
        # Выводим результат:
        print("На ипотеку было потрачено: ", int(mortgage_year),sep="") # добавил перевод строки, для красоты
        print("Было накоплено: ", int(balance),sep="")
        
except (TypeError, ValueError):
    print('Ошибка ввода данных')
# Out:
# Введите заработанную плату в месяц:100000
# Введите сколько процентов уходит на ипотеку:30
# Введите сколько процентов уходит на жизнь:50
# Введите количество премий за год:2
# На ипотеку было потрачено: 360000
# Было накоплено: 340000
